# %% [markdown]
# # Import dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import squarify
import time
import matplotlib.pyplot as plt
from datetime import datetime
import gc

import functions

# %%
df_Nov = functions.load_data('Nov')

df_Nov = functions.df_parsed(df_Nov)

# %%
# To speed things up and program what's needed, let's consider a sample of the whole dataset
sample = df_Nov.sample(n=100000, random_state=42)

# %%
gc.collect()
# Out:
# 40

# %% [markdown]
# ## [RQ1]
# A marketing funnel describes your customer’s journey with your e-commerce. It may involve different stages, beginning when someone learns about your business, when he/she visits your website for the first time, to the purchasing stage, marketing
# funnels map routes to conversion and beyond. Suppose your funnel involves just three simple steps: 1) view, 2) cart, 3) purchase. Which is the rate of complete funnels?

# %% [markdown]
# # 1.a
# What’s the operation users repeat more on average within a session? Produce a plot that shows the average number of times users perform each operation (view/removefromchart etc etc).

# %% [markdown]
# ### 1.b
# How many times, on average, a user views a product before adding it to the cart?

# %% [markdown]
# ### 1.c
# What’s the probability that products added once to the cart are effectively bought?

# %% [markdown]
# ### 1.d
# What’s the average time an item stays in the cart before being removed?

# %% [markdown]
# # 1.e
# How much time passes on average between the first view time and a purchase/addition to cart?

# %%
functions.view_purch_avg_time(sample)
# Out:
# Timedelta('1 days 22:21:09.690476')

# %% [markdown]
# ## [RQ3]
# For each category, what’s the brand whose prices are higher on average?

# %% [markdown]
# ### 3.a
# Write a function that asks the user a category in input and returns a plot indicating the average price of the products sold by the brand.

# %%
# e.g., if `category = 2053013555631882655

functions.avg_price_cat(df_Nov, 2053013555631882655)

# %% [markdown]
# ### 3.b
# Find, for each category, the brand with the highest average price. Return all the results in ascending order by price.

# %%
functions.highest_price_brands(df_Nov)
# Out:
# ['kapousprofessional',
#  'heinz',
#  'crockid',
#  'crockid',
#  'triumph',
#  'crockid',
#  'pnb',
#  'kabrita',
#  'polaris',
#  'estel',
#  'tarkett',
#  'barer',
#  'boyscout',
#  'tontarelli',
#  'pupa',
#  'alcon',
#  'bestway',
#  'ritmix',
#  'arua',
#  'bestway',
#  'denso',
#  'pupa',
#  'joerex',
#  'tega',
#  'serebro',
#  'irit',
#  'pupa',
#  'concept',
#  'prosperplast',
#  'remington',
#  'ballarini',
#  'londa',
#  'toro',
#  'samo',
#  'ecotex',
#  'prestiz',
#  'popurri',
#  'gamma',
#  'karaja',
#  'houseofseasons',
#  'maxler',
#  'eskar',
#  'bergner',
#  'ast',
#  'karya',
#  'tarkett',
#  'duo',
#  'zubr',
#  'timson',
#  'wellberg',
#  'polaris',
#  'taller',
#  'mediheal',
#  'dwt',
#  'bestway',
#  'merries',
#  'xiaomi',
#  'finezza',
#  'blenderbottle',
#  'ves',
#  'now',
#  'usborne',
#  'denzel',
#  'nutrend',
#  'fabretti',
#  'total',
#  'x-game',
#  'xiaomi',
#  'orico',
#  'palisad',
#  'wurth',
#  'hoco',
#  'jasmine',
#  'milavitsa',
#  'bergner',
#  'smashbox',
#  'gerat',
#  'noryalli',
#  'ccm',
#  'carters',
#  'carters',
#  'riche',
#  'kabrita',
#  'mof',
#  'bsn',
#  'stanley',
#  'kolibri',
#  'greyder',
#  'coopervision',
#  'lancome',
#  'petek',
#  'norplast',
#  'carfashion',
#  'crown',
#  'prologic',
#  'noppies',
#  'polaris',
#  'yvessaintlaurent',
#  'scivation',
#  'nike',
#  'bombbar',
#  'dirkje',
#  'nanga',
#  'elf',
#  'salewa',
#  'respect',
#  'yvessaintlaurent',
#  'resanta',
#  'nascitaprofessional',
#  'yvessaintlaurent',
#  'dvizenie',
#  'tefal',
#  'vladi',
#  'shiseido',
#  'grandvictory',
#  'legrand',
#  'samsung',
#  'samsung',
#  'didistyle',
#  'fabretti',
#  'intex',
#  'machaon',
#  'lorelli',
#  'fea',
#  'mora',
#  'tognana',
#  'omron',
#  'christina',
#  'panasonic',
#  'cellucor',
#  'bartek',
#  'waspo',
#  'pablosky',
#  'pablosky',
#  'bestway',
#  'biotech',
#  'kovea',
#  'penny',
#  'minimen',
#  'nike',
#  'collistar',
#  'omnimount',
#  'gucci',
#  'vitek',
#  'asus',
#  'cobra',
#  'dinamical',
#  'clatronic',
#  'redmond',
#  'pablosky',
#  'omron',
#  'bosch',
#  'tamiteks',
#  'greyder',
#  'sun',
#  'vt',
#  'smashbox',
#  'sony',
#  'caprice',
#  'arsi',
#  'make-upatelier',
#  'shagovita',
#  'converse',
#  'delonghi',
#  'esse',
#  'pablosky',
#  'salamander',
#  'noppies',
#  'petek',
#  'tamiteks',
#  'dewalt',
#  'parkmaster',
#  'onhillsport',
#  'bosch',
#  'apple',
#  'stiga',
#  'greyder',
#  'greyder',
#  'nike',
#  'tamaris',
#  'smashbox',
#  'philips',
#  'fischer',
#  'muscletech',
#  'ccm',
#  'delonghi',
#  'kerastase',
#  'nioxin',
#  'greyder',
#  'bruder',
#  'huawei',
#  'appollo',
#  'lucente',
#  'xiaomi',
#  'conceptclub',
#  'omron',
#  'stiga',
#  'hayali',
#  'harley-davidson',
#  'aurora',
#  'electronicarts',
#  'sony',
#  'ferrino',
#  'ramili',
#  'molten',
#  'atelier',
#  'moulinex',
#  'spiegelau',
#  'inglesina',
#  'josephjoseph',
#  'kaemingkbv',
#  'gerat',
#  'leone',
#  'onlitop',
#  'spaquatoria',
#  'jordan',
#  'tomfarr',
#  'traxxas',
#  'maytoni',
#  'payot',
#  'xiaomi',
#  'farmavita',
#  'krause',
#  'shagovita',
#  'milavitsa',
#  'dam',
#  'cantra',
#  'patrino',
#  'dragonfly',
#  'leatherman',
#  'carver',
#  'logitech',
#  'wilson',
#  'shagovita',
#  'ecocool',
#  'dariush',
#  'shiseido',
#  'askona',
#  'vinzer',
#  'electrolux',
#  'remington',
#  'belashoff',
#  'omero',
#  'etor',
#  'standart',
#  'mantra',
#  'askona',
#  'etor',
#  'etor',
#  'musclepharm',
#  'philips',
#  'head',
#  'stiga',
#  'hohner',
#  'stels',
#  'gabor',
#  'atlant',
#  'philips',
#  'alpina',
#  'harley-davidson',
#  'fenix',
#  'shagovita',
#  'mima',
#  'pituso',
#  'gipfel',
#  'fujifilm',
#  'anon',
#  'escada',
#  'ski-doo',
#  'ersport',
#  'magma',
#  'profiko',
#  'biotech',
#  'makita',
#  'shagovita',
#  'shimano',
#  'razer',
#  'vaiper',
#  'medela',
#  'mora',
#  'dremel',
#  'terminus',
#  'edufun',
#  'rals',
#  'saeshin',
#  'apple',
#  'braun',
#  'gipfel',
#  'roca',
#  'tramontina',
#  'greyder',
#  'makeblock',
#  'holicy',
#  'parklon',
#  'shimano',
#  'yamaha',
#  'salamander',
#  'rosato',
#  'thule',
#  'columbia',
#  'smartrike',
#  'g.skill',
#  'bosch',
#  'greyder',
#  'greyder',
#  'manfrotto',
#  'hayali',
#  'ccm',
#  'pinskdrev',
#  'spinmaster',
#  'apple',
#  'leica',
#  'reima',
#  'paiste',
#  'rostok-mebel',
#  'native',
#  'qplay',
#  'thule',
#  'ara',
#  'bosch',
#  'hasbro',
#  'cayin',
#  'kovea',
#  'artmusical',
#  'micio',
#  'reima',
#  'westerndigital',
#  'fly',
#  'ikea',
#  'marcomenti',
#  'corsair',
#  'daiwa',
#  'internedoors',
#  'permanence',
#  'technomax',
#  'gretsch',
#  'ikea',
#  'imperial',
#  'zubr',
#  'andeks',
#  'cocoonababy',
#  'cybex',
#  'neoline',
#  'erlit',
#  'waterpik',
#  'foxconn',
#  'asus',
#  'zubr',
#  'bosch',
#  'genlog',
#  'fitbit',
#  'glasman',
#  'apple',
#  'ssm',
#  'leefitness',
#  'akvaton',
#  'intex',
#  'hp',
#  'garmin',
#  'grohe',
#  'dewalt',
#  'jordan',
#  'akvarel',
#  'karcher',
#  'halmar',
#  'corsair',
#  'jaguar',
#  'thule',
#  'sv',
#  'berghoff',
#  'weekend',
#  'amazon',
#  'tomfarr',
#  'norfin',
#  'sv',
#  'burton',
#  'bts',
#  'can-am',
#  'coccinelle',
#  'lux',
#  'epson',
#  'hangover',
#  'crescina',
#  'belux',
#  'berkut',
#  'nuna',
#  'dds',
#  'housefit',
#  'battipav',
#  'appollo',
#  'apple',
#  'kenwood',
#  'burton',
#  'canon',
#  'omoikiri',
#  'atlantic',
#  'condtrol',
#  'kitchenaid',
#  'vaude',
#  'intel',
#  'fissman',
#  'ezetil',
#  'satura',
#  'carlsbad',
#  'bestway',
#  'aquavis',
#  'roncato',
#  'polaris',
#  'xp-pen',
#  'milwaukee',
#  'metabo',
#  'tacx',
#  'bork',
#  'ski-doo',
#  'samsung',
#  'comma',
#  'ikea',
#  'weber',
#  'harley-davidson',
#  'ombra',
#  'bosch',
#  'thrustmaster',
#  'husqvarna',
#  'magnetta',
#  'apple',
#  'e-blue',
#  'harley-davidson',
#  'mibb',
#  'norfin',
#  'makita',
#  'amouage',
#  'kitchenaid',
#  'wagner',
#  'delonghi',
#  'liebherr',
#  'centrpravilnogosna',
#  'weekend',
#  'lucente',
#  'thermaltake',
#  'kitfort',
#  'remington',
#  'kitchenaid',
#  'sony',
#  'remo',
#  'egreat',
#  'sony',
#  'kelly',
#  'asustor',
#  'laston',
#  'audison',
#  'dcshoes',
#  'simpleparenting',
#  'blackvue',
#  'roxy',
#  'airwheel',
#  'ikkm',
#  'emer',
#  'gardena',
#  'makita',
#  'sony',
#  'smoby',
#  'weekend',
#  'dowontec',
#  'alexika',
#  'head',
#  'brw',
#  'olsa',
#  'weekend',
#  'redpower',
#  'mebelson',
#  'metabo',
#  'weekend',
#  'dinastia',
#  'yamaha',
#  'leica',
#  'shiraz',
#  'bresser',
#  'ikea',
#  'bose',
#  'realflame',
#  'laufen',
#  'kolibri',
#  'markbass',
#  'volcano',
#  'denzel',
#  'sony',
#  'preciosa',
#  'salomon',
#  'canon',
#  'weekend',
#  'festool',
#  'bork',
#  'karcher',
#  'holicy',
#  'blam',
#  'metabo',
#  'roland',
#  'garmin',
#  'smeg',
#  'garmin',
#  'humminbird',
#  'mima',
#  'casada',
#  'smeg',
#  'evga',
#  'makita',
#  'lg',
#  'jasic',
#  'viking',
#  'dyson',
#  'electrolux',
#  'robertobravo',
#  'alpicool',
#  'jetem',
#  'novigo',
#  'higashi',
#  'festool',
#  'bosch',
#  'startradingab',
#  'fender',
#  'sv',
#  'panasonic',
#  'minelab',
#  'aorus',
#  'smeg',
#  'dewalt',
#  'roland',
#  'libero',
#  'dewalt',
#  'kitchenaid',
#  'denon',
#  'am.pm',
#  'giant',
#  'weekend',
#  'bork',
#  'festool',
#  'kuppersberg',
#  'smeg',
#  'daewoo',
#  'takamine',
#  'rinnai',
#  'permanence',
#  'htc',
#  'weekend',
#  'thule',
#  'apple',
#  'robertobravo',
#  'jasic',
#  'aero',
#  'artel',
#  'lutian',
#  'kettler',
#  'hyundai',
#  'fly',
#  'brw',
#  'makita',
#  'fitlux',
#  'lenso',
#  'mima',
#  'fitlux',
#  'lubimyjdom',
#  'silva',
#  'ostamebel',
#  'makita',
#  'robertobravo',
#  'kawai',
#  'microsoft',
#  'pinskdrev',
#  'renegade',
#  'helvetia',
#  'alkor',
#  'babylock',
#  'canon',
#  'jura',
#  'robertobravo',
#  'dayun',
#  'yamaha',
#  'smeg',
#  'electrolux',
#  'mercury',
#  'neumann',
#  'laurastar',
#  'kuppersbusch',
#  'defredesign',
#  'lg',
#  'tamron',
#  'bosch',
#  'minimotors',
#  'bafang',
#  'russia',
#  'apple',
#  'babylock',
#  'kettler',
#  'peda',
#  'aerosystem',
#  'omabelle',
#  'fubag',
#  'smeg',
#  'apple',
#  'rado',
#  'fitlux',
#  'xiaomi',
#  'dynacord',
#  'kaiser',
#  'husqvarna',
#  'apple',
#  'pinskdrev',
#  'panasonic',
#  'cartier']

# %% [markdown]
# ## [RQ5]
# In what part of the day is your store most visited? Knowing which days of the week or even which hours of the day shoppers are likely to visit your online store and make a purchase may help you improve your strategies. Create a plot that for each day of
# the week show the hourly average of visitors your store has.

# %%
# Use sample for time reasons

functions.avg_users(sample)

# %% [markdown]
# ## [RQ7]
# The Pareto principle states that for many outcomes roughly 80% of consequences come from 20% of the causes. Also known as 80/20 rule, in e-commerce simply means that most of your business, around 80%, likely comes from about 20% of your
# customers.
#
# Prove that the pareto principle applies to your store.

# %%
print('20% of the users in the ecommerce provide for {:.2f} of the entire business.'.format(functions.pareto_principle(df_Nov)))
# Out:
# 20% of the users in the ecommerce provide for 69.64 of the entire business.

# %%
print('25% of the users in the ecommerce provide for {:.2f} of the entire business.'.format(functions.pareto_principle(df_Nov, 25)))
# Out:
# 25% of the users in the ecommerce provide for 75.30 of the entire business.

# %% [markdown]
# #### Observations
#
# As we can see in the previous cells, the Pareto principle is respected (with a 75/25 ratio).
#
# Moreover, we can also analyze the behaviour with respect to the percentage of users considered. If we look at the plot below, we can see that 10% of the users already provide for more than half of the whole business. Also, from the 50% point on, we can see that the whole business is almost completely conducted by by the first half of the users.

# %%
functions.plot_pareto(df_Nov)
